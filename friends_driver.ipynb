# %% [markdown]
# # Neo4j Hello World (Notebook) - Friends Use Case
#
# This notebook connects to a local Neo4j **Community** instance (via Docker), creates a tiny graph, and queries it.
#
# **Assumes**
#
#
# - Neo4j service is running at `bolt://localhost:${URI_PORT}` with the user and password set in the `.env` file. **Run `docker compose up -d`**.
# - Ollama service is up on `http://localhost:11434` (ollama default). **Run `ollama serve` and pull the model `ollama pull nomic-embed-text`** (if not pulled yet).

# %%
# Dependencies

import os
from dotenv import load_dotenv  
import yaml
from pathlib import Path
from pprint import pprint
from termcolor import cprint
from neo4j import GraphDatabase

from helpers import helper_folium, helper_leaflet, helper_neo4j, helper_ollama

# %%
# Environment variables

load_dotenv()  # Load local environment variables

URI = "bolt://localhost:" + os.environ.get("URI_PORT")
NEO4J_USER = os.environ.get("NEO4J_USER")
NEO4J_PWD = os.environ.get("NEO4J_PASSWORD")
NEO4J_DB = os.getenv("NEO4J_DATABASE", "neo4j")    # 👈 choose DB here

cprint(f"Connecting to Neo4j at {URI} with user {NEO4J_USER} and password {NEO4J_PWD}", "green")
# Out:
# Connecting to Neo4j at bolt://localhost:7687 with user neo4j and password test1234

# %%
# Load cypher queries

queries = yaml.safe_load(Path("data/friends/queries_friends.yaml").read_text())
queries.keys()  # list available queries
# Out:
# dict_keys(['constraints', 'create_seed', 'show_people', 'show_companies', 'match_adjacency', 'show_text', 'show_locations', 'show_distances', 'add_text', 'add_locations', 'create_vector_indexes', 'delete_all'])

# %%
# Neo4j Driver instance

driver = GraphDatabase.driver(uri=URI, auth=(NEO4J_USER, NEO4J_PWD))

# %% [markdown]
# ### 1. Create data

# %% [markdown]
# <p align="center">
#   <img src="media/KG_step1_populate_graph.svg" width="550">
# </p>
#
#
# - **Entities**: Person and Company nodes with unique constraints (unique name and uuid)
# - **Relationships**: KNOWS (person-to-person) and WORKS_AT (person-to-company)
# - **Properties**: Basic attributes (name, age, education, industry)

# %%
# Populate graph

with driver.session(database=NEO4J_DB) as session:
    
    dbinfo = session.run("CALL db.info()").single()
    cprint(f"\nConnected to Neo4j database: {dbinfo['name']}", "green")
    
    cprint("\nCreating constraints (if not exist)", "green")
    for c in queries["constraints"]:
        session.run(c)
    
    cprint("\nInit Cleanup.", "green")
    for q in queries["delete_all"]:
        session.run(q)
        
    cprint("\nCreate data", "green")
    session.run(queries["create_seed"])

    cprint("\nQuery: list all people", "green")
    records = session.run(queries["show_people"]) # <class 'neo4j.work.result.Result'>, convert to  <class 'list'> to see contents: list(records)
    for r in records:
        print(dict(r))
        
    cprint("\nQuery: list all companies", "green")
    records = session.run(queries["show_companies"]) # <class 'neo4j.work.result.Result'>, convert to  <class 'list'> to see contents: list(records)
    for r in records:
        print(dict(r))

    cprint("\nQuery: adjacency (who knows whom)", "green")
    records = session.run(queries["match_adjacency"]) # <class 'neo4j.work.result.Result'>, convert to  <class 'list'> to see contents: list(records)
    for r in records:
        print(dict(r))
# Out:
# Connected to Neo4j database: neo4j
#
# Creating constraints (if not exist)
#
# Init Cleanup.
#
# Create data
#
# Query: list all people
# {'name': 'Paula', 'age': 25, 'p.gender': 'female', 'education': 'Computer Engineering'}
# {'name': 'Guillermo', 'age': 26, 'p.gender': 'male', 'education': 'Industrial Engineering'}
# {'name': 'Gabriela', 'age': 26, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Iciar', 'age': 26, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Cristina', 'age': 27, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Daniel', 'age': 27, 'p.gender': 'male', 'education': 'Arts'}
# {'name': 'Javier', 'age': 27, 'p.gender': 'male', 'education': 'Physics'}
# {'name': 'Juan', 'age': 27, 'p.gender': 'male', 'education': 'Physics'}
# {'name': 'Adrián', 'age': 27, 'p.gender': 'male', 'education': 'Physics'}
# {'name': 'Iria', 'age': 27, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Elias', 'age': 29, 'p.gender': 'male', 'education': 'Physics'}
#
# Query: list all companies
# {'name': 'Getronics', 'industry': 'Consulting Services'}
# {'name': 'Accenture', 'industry': 'Consulting Services'}
# {'name': 'Indra', 'industry': 'Engineering'}
# {'name': 'CIEMAT', 'industry': 'Scientific Research'}
# {'name': 'CBM', 'industry': 'Scientific Research'}
# {'name': 'Instagram', 'industry': 'Social Media'}
#
# Query: adjacency (who knows whom)
# {'person': 'Adrián', 'knows': ['Juan', 'Elias', 'Iciar', 'Javier', 'Gabriela', 'Cristina', 'Iria'], 'works_at': 'Indra'}
# {'person': 'Cristina', 'knows': ['Daniel', 'Iciar', 'Elias', 'Javier', 'Juan', 'Adrián', 'Gabriela', 'Iria'], 'works_at': 'CBM'}
# {'person': 'Daniel', 'knows': ['Cristina'], 'works_at': 'Instagram'}
# {'person': 'Elias', 'knows': ['Cristina', 'Iciar', 'Juan', 'Adrián', 'Javier', 'Gabriela', 'Iria'], 'works_at': 'Accenture'}
# {'person': 'Gabriela', 'knows': ['Iciar', 'Elias', 'Adrián', 'Juan', 'Javier', 'Cristina', 'Iria'], 'works_at': 'CIEMAT'}
# {'person': 'Guillermo', 'knows': ['Paula', 'Iria'], 'works_at': 'Indra'}
# {'person': 'Iciar', 'knows': ['Cristina', 'Elias', 'Javier', 'Gabriela', 'Juan', 'Adrián', 'Iria'], 'works_at': 'Accenture'}
# {'person': 'Iria', 'knows': ['Adrián', 'Iciar', 'Elias', 'Juan', 'Javier', 'Cristina', 'Paula', 'Gabriela', 'Guillermo'], 'works_at': 'Indra'}
# {'person': 'Javier', 'knows': ['Iciar', 'Cristina', 'Juan', 'Elias', 'Adrián', 'Gabriela', 'Iria'], 'works_at': 'Indra'}
# {'person': 'Juan', 'knows': ['Adrián', 'Elias', 'Cristina', 'Javier', 'Iciar', 'Gabriela', 'Iria'], 'works_at': 'Getronics'}
# {'person': 'Paula', 'knows': ['Guillermo', 'Iria'], 'works_at': 'Indra'}

# %%
# Example cypher queries

with driver.session(database=NEO4J_DB) as session:

    cprint("\nQuery: list all people", "green")
    records = session.run(queries["show_people"]) # <class 'neo4j.work.result.Result'>, convert to  <class 'list'> to see contents: list(records)
    for r in records:
        print(dict(r))
        
    cprint("\nQuery: list all companies", "green")
    records = session.run(queries["show_companies"]) # <class 'neo4j.work.result.Result'>, convert to  <class 'list'> to see contents: list(records)
    for r in records:
        print(dict(r))

    cprint("\nQuery: adjacency (who knows whom)", "green")
    records = session.run(queries["match_adjacency"]) # <class 'neo4j.work.result.Result'>, convert to  <class 'list'> to see contents: list(records)
    for r in records:
        print(dict(r))
# Out:
# Query: list all people
# {'name': 'Paula', 'age': 25, 'p.gender': 'female', 'education': 'Computer Engineering'}
# {'name': 'Guillermo', 'age': 26, 'p.gender': 'male', 'education': 'Industrial Engineering'}
# {'name': 'Gabriela', 'age': 26, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Iciar', 'age': 26, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Cristina', 'age': 27, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Daniel', 'age': 27, 'p.gender': 'male', 'education': 'Arts'}
# {'name': 'Javier', 'age': 27, 'p.gender': 'male', 'education': 'Physics'}
# {'name': 'Juan', 'age': 27, 'p.gender': 'male', 'education': 'Physics'}
# {'name': 'Adrián', 'age': 27, 'p.gender': 'male', 'education': 'Physics'}
# {'name': 'Iria', 'age': 27, 'p.gender': 'female', 'education': 'Physics'}
# {'name': 'Elias', 'age': 29, 'p.gender': 'male', 'education': 'Physics'}
#
# Query: list all companies
# {'name': 'Getronics', 'industry': 'Consulting Services'}
# {'name': 'Accenture', 'industry': 'Consulting Services'}
# {'name': 'Indra', 'industry': 'Engineering'}
# {'name': 'CIEMAT', 'industry': 'Scientific Research'}
# {'name': 'CBM', 'industry': 'Scientific Research'}
# {'name': 'Instagram', 'industry': 'Social Media'}
#
# Query: adjacency (who knows whom)
# {'person': 'Adrián', 'knows': ['Juan', 'Elias', 'Iciar', 'Javier', 'Gabriela', 'Cristina', 'Iria'], 'works_at': 'Indra'}
# {'person': 'Cristina', 'knows': ['Daniel', 'Iciar', 'Elias', 'Javier', 'Juan', 'Adrián', 'Gabriela', 'Iria'], 'works_at': 'CBM'}
# {'person': 'Daniel', 'knows': ['Cristina'], 'works_at': 'Instagram'}
# {'person': 'Elias', 'knows': ['Cristina', 'Iciar', 'Juan', 'Adrián', 'Javier', 'Gabriela', 'Iria'], 'works_at': 'Accenture'}
# {'person': 'Gabriela', 'knows': ['Iciar', 'Elias', 'Adrián', 'Juan', 'Javier', 'Cristina', 'Iria'], 'works_at': 'CIEMAT'}
# {'person': 'Guillermo', 'knows': ['Paula', 'Iria'], 'works_at': 'Indra'}
# {'person': 'Iciar', 'knows': ['Cristina', 'Elias', 'Javier', 'Gabriela', 'Juan', 'Adrián', 'Iria'], 'works_at': 'Accenture'}
# {'person': 'Iria', 'knows': ['Adrián', 'Iciar', 'Elias', 'Juan', 'Javier', 'Cristina', 'Paula', 'Gabriela', 'Guillermo'], 'works_at': 'Indra'}
# {'person': 'Javier', 'knows': ['Iciar', 'Cristina', 'Juan', 'Elias', 'Adrián', 'Gabriela', 'Iria'], 'works_at': 'Indra'}
# {'person': 'Juan', 'knows': ['Adrián', 'Elias', 'Cristina', 'Javier', 'Iciar', 'Gabriela', 'Iria'], 'works_at': 'Getronics'}
# {'person': 'Paula', 'knows': ['Guillermo', 'Iria'], 'works_at': 'Indra'}

# %% [markdown]
# ### 2.A. Add rich text info

# %% [markdown]
# <p align="center">
#   <img src="media/KG_step2_generate_rich_descriptions.svg" width="750">
# </p>

# %%
# Add rich text descriptions 

with driver.session(database=NEO4J_DB) as session:

    cprint("\nQuery: Adding descriptions, appearance and summaries", "green")
    for q in queries["add_text"]:
        session.run(q)
# Out:
# Query: Adding descriptions, appearance and summaries

# %% [markdown]
# ### 2.B Add location info

# %%
# Add location property 

with driver.session(database=NEO4J_DB) as session:

    cprint("\nQuery: Adding location property", "green")
    for q in queries["add_locations"]:
        session.run(q)
# Out:
# Query: Adding location property

# %%
# Show locations and plot maps

with driver.session(database=NEO4J_DB) as session:

    cprint("\nQuery: Adding location property", "green")
    results = session.run(queries["show_locations"])
    records = list(results)

# Replace with your query result rows
# records = [
#     {"name":"Iria","lat":40.437596,"lon":-3.711223,"labels":["Person"]},
#     {"name":"Guillermo","lat":40.455022,"lon":-3.692355,"labels":["Person"]},
#     {"name":"Gabriela","lat":40.475721,"lon":-3.711451,"labels":["Person"]},
#     {"name":"Paula","lat":40.490170,"lon":-3.654654,"labels":["Person"]},
#     {"name":"Cristina","lat":40.367462,"lon":-3.597745,"labels":["Person"]},
#     {"name":"Indra","lat":40.396648,"lon":-3.624635,"labels":["Company"]},
#     {"name":"CIEMAT","lat":40.453938,"lon":-3.728925,"labels":["Company"]},
#     {"name":"CBM","lat":40.549613,"lon":-3.690136,"labels":["Company"]},
# ]
for r in records:
    print(dict(r))

# Follium map
helper_folium.create_map_from_rows(records)

# Leaflet map
helper_leaflet.create_map_from_rows(records)
# Out:
# Query: Adding location property
# {'name': 'Guillermo', 'labels': ['Person'], 'lat': 40.455022, 'lon': -3.692355}
# {'name': 'Gabriela', 'labels': ['Person'], 'lat': 40.4328, 'lon': -3.711451}
# {'name': 'Paula', 'labels': ['Person'], 'lat': 40.49017, 'lon': -3.654654}
# {'name': 'Cristina', 'labels': ['Person'], 'lat': 40.4332, 'lon': -3.597745}
# {'name': 'Daniel', 'labels': ['Person'], 'lat': 40.4336, 'lon': -3.617745}
# {'name': 'Javier', 'labels': ['Person'], 'lat': 40.434, 'lon': -3.711223}
# {'name': 'Juan', 'labels': ['Person'], 'lat': 40.4344, 'lon': -3.711223}
# {'name': 'Elias', 'labels': ['Person'], 'lat': 40.4348, 'lon': -3.711223}
# {'name': 'Iciar', 'labels': ['Person'], 'lat': 40.4352, 'lon': -3.711223}
# {'name': 'Adrián', 'labels': ['Person'], 'lat': 40.4356, 'lon': -3.711223}
# {'name': 'Indra', 'labels': ['Company'], 'lat': 40.533873, 'lon': -3.630539}
# {'name': 'CIEMAT', 'labels': ['Company'], 'lat': 40.453938, 'lon': -3.728925}
# {'name': 'CBM', 'labels': ['Company'], 'lat': 40.549613, 'lon': -3.690136}
# {'name': 'Instagram', 'labels': ['Company'], 'lat': 40.652321, 'lon': -3.701249}
# {'name': 'Getronics', 'labels': ['Company'], 'lat': 40.352321, 'lon': -3.801249}
# {'name': 'Accenture', 'labels': ['Company'], 'lat': 40.651321, 'lon': -3.801249}
# {'name': 'Iria', 'labels': ['Person'], 'lat': 40.4336, 'lon': -3.711223}
# Map saved to data/friends/friends_map_folium.html
# Map saved to data/friends/friends_map_leaflet.html

# %% [markdown]
# ### 3. Create property embeddings (first step into RAG)

# %% [markdown]
# <p align="center">
#   <img src="media/KG_step3_generate_property_embeddings.svg" width="750">
# </p>
#
# **RAG** implementation requires selecting a **property to embed and use for similarity searches**.
#
# Description properties containing **rich text** work well for this purpose, as they provide richer semantic information. In our example, we'll use *text*.
#
# In order to do so, we create two vector indexes in Neo4j:
#
# - **Vector index *person_node_info_idx***: based on property ***info_emb*** for nodes of type "Person"
# -  **Vector index *company_node_info_idx***: based on property ***info_emb*** for nodes of type "Company"
#
# After that, we create the embeddings (this happens for both Person nodes and Company nodes):
#
# - **Property *text*** ---`nomic-embed-text`---> **Property *embedding***

# %%
# Create vector indexes

with driver.session(database=NEO4J_DB) as session:
    
    for q in queries["create_vector_indexes"]:
        session.run(q)
    
    # Show created vector indexes
    results = session.run("SHOW VECTOR INDEXES")
    idx = list(results)
    cprint(f"\nFound {len(idx)} vector index entries.", "green")
    for r in idx:
        cprint("-"*20,"green")
        pprint(dict(r))
# Out:
# Found 3 vector index entries.
# --------------------
# {'entityType': 'NODE',
#  'id': 11,
#  'indexProvider': 'vector-2.0',
#  'labelsOrTypes': ['Company'],
#  'lastRead': None,
#  'name': 'company_node_idx',
#  'owningConstraint': None,
#  'populationPercent': 100.0,
#  'properties': ['embedding'],
#  'readCount': None,
#  'state': 'ONLINE',
#  'type': 'VECTOR'}
# --------------------
# {'entityType': 'RELATIONSHIP',
#  'id': 12,
#  'indexProvider': 'vector-2.0',
#  'labelsOrTypes': ['KNOWS'],
#  'lastRead': None,
#  'name': 'know_relationship_idx',
#  'owningConstraint': None,
#  'populationPercent': 100.0,
#  'properties': ['embedding'],
#  'readCount': None,
#  'state': 'ONLINE',
#  'type': 'VECTOR'}
# --------------------
# {'entityType': 'NODE',
#  'id': 10,
#  'indexProvider': 'vector-2.0',
#  'labelsOrTypes': ['Person'],
#  'lastRead': None,
#  'name': 'person_node_idx',
#  'owningConstraint': None,
#  'populationPercent': 100.0,
#  'properties': ['embedding'],
#  'readCount': None,
#  'state': 'ONLINE',
#  'type': 'VECTOR'}

# %%
# Create property embeddings 

with driver.session(database=NEO4J_DB) as session:
    
    # (p:PERSON): create embeddings only for nodes missing them
    helper_neo4j.vectorize_property(runner = session.run,
                       element = "node", 
                       node_label = "Person",
                       source_property = "text", 
                       )
    
    # (c:COMPANY): create embeddings only for nodes missing them
    helper_neo4j.vectorize_property(runner = session.run,
                       element = "node", 
                       node_label = "Company", 
                       source_property = "text", 
                       )    
    
    # [r:KNOWS]: create embeddings only for nodes missing them
    helper_neo4j.vectorize_property(runner = session.run,
                       element = "relationship",
                       rel_type = "KNOWS",
                       source_property = "text",
                       )
# Out:
# Generating embeddings for (n:Person) on n.text
#
# Generating embeddings
#   input text: 'Guillermo is a male of 26 years old and studied In'...
#   emb vec: [-0.023262369, 0.05322417, -0.15030223, 0.0006475813, -0.024272997, 0.068250276, 0.06251268, -0.028424125, -0.00060151465, 0.016591795]
#
#
# Generating embeddings
#   input text: 'Gabriela is a female of 26 years old and studied P'...
#   emb vec: [0.028215451, 0.02993047, -0.18000375, 0.032270715, -0.040491913, 0.081315376, 0.0066461083, -0.050384577, -0.04074791, -0.018135754]
#
#
# Generating embeddings
#   input text: 'Paula is a female of 25 years old and studied Comp'...
#   emb vec: [0.011417965, 0.040603343, -0.16852917, -0.01312405, -0.036922883, 0.08387193, -0.01419786, -0.018175317, -0.05579591, 0.006982089]
#
#
# Generating embeddings
#   input text: 'Cristina is a female of 27 years old and studied P'...
#   emb vec: [0.032263294, -0.0020466913, -0.157968, -0.01176661, -0.00407553, 0.068459205, 0.028425619, -0.047500443, -0.0067735366, 0.028148634]
#
#
# Generating embeddings
#   input text: 'Daniel is a male of 27 years old and studied Arts.'...
#   emb vec: [-0.030130444, -0.01133115, -0.14154036, -0.049251076, -0.015897753, 0.07873104, 0.0017852066, 0.012523586, 0.008711668, -0.040770568]
#
#
# Generating embeddings
#   input text: 'Javier is a male of 27 years old and studied Physi'...
#   emb vec: [0.007926779, 0.034412425, -0.16499165, 0.0059885117, -0.011221225, 0.075421676, -0.016736047, -0.02090438, -0.042530626, 0.016653325]
#
#
# Generating embeddings
#   input text: 'Juan is a male of 27 years old and studied Physics'...
#   emb vec: [-0.00539993, 0.037996944, -0.16215289, -0.0071134646, 0.0139899915, 0.06966817, -0.0049025496, -0.062390126, -0.00787202, -0.040535733]
#
#
# Generating embeddings
#   input text: 'Elias is a male of 29 years old and studied Physic'...
#   emb vec: [-0.0285582, 0.022214333, -0.1743958, -0.072415076, 0.037062075, 0.05783049, 0.011507059, 0.0069581047, -0.0013908206, -0.02899461]
#
#
# Generating embeddings
#   input text: 'Iciar is a female of 26 years old and studied Phys'...
#   emb vec: [0.016377574, 0.054755904, -0.19647865, -0.018668214, 0.02150206, 0.068144046, 0.01780152, -0.07202785, -0.013024305, 0.021203704]
#
#
# Generating embeddings
#   input text: 'Adrián is a male of 27 years old and studied Physi'...
#   emb vec: [-0.012973069, 0.011709854, -0.16225867, -0.07413695, 0.035886694, 0.10010045, 0.019547826, -0.029478552, 0.03284196, -0.009140282]
#
#
# Generating embeddings
#   input text: 'Iria is a female of 27 years old and studied Physi'...
#   emb vec: [0.031421136, 0.032104157, -0.15766615, -0.02647035, -0.007289977, 0.053833045, 0.028187405, -0.04293681, 0.020300867, 0.038549334]
#
#
# Generating embeddings for (n:Company) on n.text
#
# Generating embeddings
#   input text: 'Indra operates in the Engineering industry.Indra G'...
#   emb vec: [-0.014035365, 0.06831103, -0.19293985, 0.012614345, 0.046351437, -0.006920077, -0.023305941, -0.048847396, -0.0086202705, -0.034771826]
#
#
# Generating embeddings
#   input text: 'CIEMAT operates in the Scientific Research industr'...
#   emb vec: [-0.0008125481, 0.0686467, -0.21528068, -0.01879254, 0.0735148, -0.023971505, 0.001505732, 0.0063486, -0.043787573, 0.018297065]
#
#
# Generating embeddings
#   input text: 'CBM operates in the Scientific Research industry.T'...
#   emb vec: [0.01750885, 0.043141548, -0.16125496, 0.017118515, 0.06423624, -0.026265021, 0.008383899, -0.022966579, 0.0017760249, -0.021226868]
#
#
# Generating embeddings
#   input text: 'Instagram operates in the Social Media industry.In'...
#   emb vec: [-0.018123278, 0.051851593, -0.17342015, 0.043099336, 0.049956992, -0.022392789, 0.043657154, -0.0025726198, 0.05764923, -0.021956878]
#
#
# Generating embeddings
#   input text: 'Getronics operates in the Consulting Services indu'...
#   emb vec: [-0.004885212, 0.08823099, -0.15822156, -0.04033393, 0.096910134, -0.011075005, -0.018583504, -0.011016131, 0.029555896, 0.034859687]
#
#
# Generating embeddings
#   input text: 'Accenture operates in the Consulting Services indu'...
#   emb vec: [-0.01927282, 0.053441748, -0.18275712, 0.019485638, 0.04887119, 0.003333449, 0.0014593204, 0.016281495, 0.03268255, 0.037024368]
#
#
# Generating embeddings for [r:KNOWS] on r.text
#
# Generating embeddings
#   input text: 'Guillermo and Iria work together in the same proje'...
#   emb vec: [-0.012557401, 0.041814107, -0.1631818, 0.034556046, 0.075751185, -0.0130899865, -0.0078845555, -0.0657379, -0.043702442, 0.06641598]
#
#   text: Guillermo and Iria work together in the same project with AI Agents.
#   vec: [-0.012557401, 0.041814107, -0.1631818]
#
# Generating embeddings
#   input text: 'Guillermo and Iria work together in the same proje'...
#   emb vec: [-0.012557401, 0.041814107, -0.1631818, 0.034556046, 0.075751185, -0.0130899865, -0.0078845555, -0.0657379, -0.043702442, 0.06641598]
#
#   text: Guillermo and Iria work together in the same project with AI Agents.
#   vec: [-0.012557401, 0.041814107, -0.1631818]
#
# Generating embeddings
#   input text: 'Iria and Gabriela now each other because they went'...
#   emb vec: [0.0056753354, -0.007195168, -0.20471278, 0.08880384, 0.022685047, 0.0725193, -0.06341527, -0.021771166, -0.022986323, 0.028575405]
#
#   text: Iria and Gabriela now each other because they went to University together and liked going camping.
#   vec: [0.0056753354, -0.007195168, -0.20471278]
#
# Generating embeddings
#   input text: 'Iria and Gabriela now each other because they went'...
#   emb vec: [0.0056753354, -0.007195168, -0.20471278, 0.08880384, 0.022685047, 0.0725193, -0.06341527, -0.021771166, -0.022986323, 0.028575405]
#
#   text: Iria and Gabriela now each other because they went to University together and liked going camping.
#   vec: [0.0056753354, -0.007195168, -0.20471278]
#
# Generating embeddings
#   input text: 'Paula is helping Iria with the project she is work'...
#   emb vec: [0.0012532333, 0.049452547, -0.18221916, -0.026781095, 0.015817089, -0.0006591388, -0.030681346, -0.021376068, -0.057444382, 0.029114354]
#
#   text: Paula is helping Iria with the project she is working on.
#   vec: [0.0012532333, 0.049452547, -0.18221916]
#
# Generating embeddings
#   input text: 'Paula is helping Iria with the project she is work'...
#   emb vec: [0.0012532333, 0.049452547, -0.18221916, -0.026781095, 0.015817089, -0.0006591388, -0.030681346, -0.021376068, -0.057444382, 0.029114354]
#
#   text: Paula is helping Iria with the project she is working on.
#   vec: [0.0012532333, 0.049452547, -0.18221916]
#
# Generating embeddings
#   input text: 'Cristina was Iria best friend in University, now t'...
#   emb vec: [0.014252732, -0.014345809, -0.17574927, 0.0051664435, 0.030922212, 0.032796707, -0.035790604, -0.051886447, -0.031440087, 0.041511558]
#
#   text: Cristina was Iria best friend in University, now they see each other every weekend.
#   vec: [0.014252732, -0.014345809, -0.17574927]
#
# Generating embeddings
#   input text: 'Cristina was Iria best friend in University, now t'...
#   emb vec: [0.014252732, -0.014345809, -0.17574927, 0.0051664435, 0.030922212, 0.032796707, -0.035790604, -0.051886447, -0.031440087, 0.041511558]
#
#   text: Cristina was Iria best friend in University, now they see each other every weekend.
#   vec: [0.014252732, -0.014345809, -0.17574927]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'Paula is helping Guillermo with the project he is '...
#   emb vec: [0.0062245666, 0.053603172, -0.15986727, -0.014526079, 0.021168413, 0.0093315, -0.018434651, -0.027455796, -0.09440517, 0.023653086]
#
#   text: Paula is helping Guillermo with the project he is working on.
#   vec: [0.0062245666, 0.053603172, -0.15986727]
#
# Generating embeddings
#   input text: 'Paula is helping Guillermo with the project he is '...
#   emb vec: [0.0062245666, 0.053603172, -0.15986727, -0.014526079, 0.021168413, 0.0093315, -0.018434651, -0.027455796, -0.09440517, 0.023653086]
#
#   text: Paula is helping Guillermo with the project he is working on.
#   vec: [0.0062245666, 0.053603172, -0.15986727]
#
# Generating embeddings
#   input text: 'Cristina and Gabriela go to Chinese academy togeth'...
#   emb vec: [0.0021362242, 0.008798516, -0.17464985, 0.07130349, 0.037650418, 0.069641255, 0.020249583, -0.058378387, -0.023055676, 0.02908613]
#
#   text: Cristina and Gabriela go to Chinese academy together, although they met at uni.
#   vec: [0.0021362242, 0.008798516, -0.17464985]
#
# Generating embeddings
#   input text: 'Cristina and Gabriela go to Chinese academy togeth'...
#   emb vec: [0.0021362242, 0.008798516, -0.17464985, 0.07130349, 0.037650418, 0.069641255, 0.020249583, -0.058378387, -0.023055676, 0.02908613]
#
#   text: Cristina and Gabriela go to Chinese academy together, although they met at uni.
#   vec: [0.0021362242, 0.008798516, -0.17464985]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'Cristina and Daniel are in a relaitonship.'...
#   emb vec: [0.024389734, -0.014437626, -0.1700786, -0.012945944, 0.02206743, 0.043086752, -0.044617746, -0.065540865, -0.00795234, 0.0016108565]
#
#   text: Cristina and Daniel are in a relaitonship.
#   vec: [0.024389734, -0.014437626, -0.1700786]
#
# Generating embeddings
#   input text: 'Cristina and Daniel are in a relaitonship.'...
#   emb vec: [0.024389734, -0.014437626, -0.1700786, -0.012945944, 0.02206743, 0.043086752, -0.044617746, -0.065540865, -0.00795234, 0.0016108565]
#
#   text: Cristina and Daniel are in a relaitonship.
#   vec: [0.024389734, -0.014437626, -0.1700786]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]
#
# Generating embeddings
#   input text: 'University friends.'...
#   emb vec: [-0.018542316, 0.01777131, -0.15750118, 0.009560419, 0.06501173, 0.062169716, -0.05369, -0.003237576, 0.020037338, 0.0367771]
#
#   text: University friends.
#   vec: [-0.018542316, 0.01777131, -0.15750118]

# %% [markdown]
# ### 4. Search

# %% [markdown]
# Whenever we query this graph, we can use two different but complementary search techniques:
#
# 1. **KG Retreival**: through **Neo4J Cypher Query Language (CQL)** we can query precise entities and relations. The input query must be translated into CQL to get the desired results.
#
# 2. **Vector Retrieval**: **embedding the input query**, we can make a vector search against the vector indexes defined above.
#
# The results will be a combination of both searches.
#
# <p align="center">
#   <img src="media/KGRAG_schema.svg">
# </p>

# %%
# KG RAG Search
import json
with driver.session(database=NEO4J_DB) as session:
  
  # Query Nodes
  result = helper_neo4j.neo4j_KGRAG_search(runner = session.run, 
                               element = "node",
                               query = "Who shaved its head this summer?", 
                               index = "person_node_idx",
                               source_property = "text",
                               main_property = "name",
                               top_k = 5
                               )
  pprint(result, width = 200, sort_dicts=False, indent=2)
  file = "data/friends/friends_context_1.txt"
  with open(file, 'w', encoding='utf-8') as f:
    f.write(result.get("combined_context", ""))


  result  = helper_neo4j.neo4j_KGRAG_search(runner = session.run, 
                                element = "node",
                                query = "Which company investigates Cancer?",
                                index = "company_node_idx",
                                source_property = "text",
                                main_property = "name",
                                top_k = 5
                                )
  
  pprint(result, width = 200, sort_dicts=False, indent=2)
  file = "data/friends/friends_context_2.txt"
  with open(file, 'w', encoding='utf-8') as f:
    f.write(result.get("combined_context", ""))
# Out:
# Generating embeddings
#   input text: 'Who shaved its head this summer?'...
#   emb vec: [0.022573026, -0.015476549, -0.17212495, 0.0018683294, -0.038688686, 0.044817436, 0.01842398, 0.013745231, 0.050375726, 0.008345599]
#
#
# Running vector search query
# { 'query': 'Who shaved its head this summer?',
#   'total_results': 0,
#   'raw_search_results': [ { 'score': 0.8374781608581543,
#                             'label': ['Person'],
#                             'properties_dict': { 'text': 'Guillermo is a male of 26 years old and studied Industrial Engineering.Guillermo has brown eyes and short hair. He has a very fancy shirt '
#                                                          'that he takes to all important events. He shaved his head this summer.',
#                                                  'location': POINT(-3.692355 40.455022),
#                                                  'name': 'Guillermo',
#                                                  'age': 26,
#                                                  'gender': 'male',
#                                                  'education': 'Industrial Engineering'},
#                             'facts': [ 'Guillermo -[WORKS_AT {"since":2023}]-> Indra',
#                                        'Guillermo -[KNOWS {"knows_from":"work","text":"Paula is helping Guillermo with the project he is working on."}]-> Paula',
#                                        'Iria -[KNOWS {"knows_from":"work","text":"Guillermo and Iria work together in the same project with AI Agents."}]-> Guillermo']},
#                           { 'score': 0.7817301750183105,
#                             'label': ['Person'],
#                             'properties_dict': { 'text': "Gabriela is a female of 26 years old and studied Physics.Gabriela has long curly hair with babylights. She's petite and likes to wear "
#                                                          'hippie-style clothes.',
#                                                  'location': POINT(-3.711451 40.4328),
#                                                  'name': 'Gabriela',
#                                                  'age': 26,
#                                                  'gender': 'female',
#                                                  'education': 'Physics'},
#                             'facts': [ 'Gabriela -[WORKS_AT {"since":2023}]-> CIEMAT',
#                                        'Gabriela -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Iciar',
#                                        'Gabriela -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Elias',
#                                        'Gabriela -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Adrián',
#                                        'Gabriela -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Juan',
#                                        'Gabriela -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Javier',
#                                        'Gabriela -[KNOWS {"knows_from":"university","text":"Cristina and Gabriela go to Chinese academy together, although they met at uni."}]-> Cristina',
#                                        'Iria -[KNOWS {"knows_from":"university","text":"Iria and Gabriela now each other because they went to University together and liked going camping."}]-> '
#                                        'Gabriela']},
#                           { 'score': 0.7744836807250977,
#                             'label': ['Person'],
#                             'properties_dict': { 'text': 'Cristina is a female of 27 years old and studied Physics.Cristina has brown eyes and very long straight brunette hair. She usually wears '
#                                                          'scarfs to style her hair and long skirts. ',
#                                                  'location': POINT(-3.597745 40.4332),
#                                                  'name': 'Cristina',
#                                                  'age': 27,
#                                                  'gender': 'female',
#                                                  'education': 'Physics'},
#                             'facts': [ 'Cristina -[KNOWS {"knows_from":"school","text":"Cristina and Daniel are in a relaitonship."}]-> Daniel',
#                                        'Cristina -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Iciar',
#                                        'Cristina -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Elias',
#                                        'Cristina -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Javier',
#                                        'Cristina -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Juan',
#                                        'Cristina -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Adrián',
#                                        'Cristina -[WORKS_AT {"since":2025}]-> CBM',
#                                        'Gabriela -[KNOWS {"knows_from":"university","text":"Cristina and Gabriela go to Chinese academy together, although they met at uni."}]-> Cristina',
#                                        'Iria -[KNOWS {"knows_from":"university","text":"Cristina was Iria best friend in University, now they see each other every weekend."}]-> Cristina']},
#                           { 'score': 0.7634782791137695,
#                             'label': ['Person'],
#                             'properties_dict': { 'text': 'Iria is a female of 27 years old and studied Physics.Iria has blue eyes and long brunette and wavy hair. She likes to paint her nails in red '
#                                                          'or purple colours. She usually wears long earrings.',
#                                                  'location': POINT(-3.711223 40.4336),
#                                                  'name': 'Iria',
#                                                  'age': 27,
#                                                  'gender': 'female',
#                                                  'education': 'Physics'},
#                             'facts': [ 'Iria -[WORKS_AT {"since":2025}]-> Indra',
#                                        'Iria -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Adrián',
#                                        'Iria -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Iciar',
#                                        'Iria -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Elias',
#                                        'Iria -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Juan',
#                                        'Iria -[KNOWS {"text":"University friends.","knows_from":"university"}]-> Javier',
#                                        'Iria -[KNOWS {"knows_from":"university","text":"Cristina was Iria best friend in University, now they see each other every weekend."}]-> Cristina',
#                                        'Iria -[KNOWS {"knows_from":"work","text":"Paula is helping Iria with the project she is working on."}]-> Paula',
#                                        'Iria -[KNOWS {"knows_from":"university","text":"Iria and Gabriela now each other because they went to University together and liked going camping."}]-> '
#                                        'Gabriela',
#                                        'Iria -[KNOWS {"knows_from":"work","text":"Guillermo and Iria work together in the same project with AI Agents."}]-> Guillermo']},
#                           { 'score': 0.7591254711151123,
#                             'label': ['Person'],
#                             'properties_dict': { 'text': 'Daniel is a male of 27 years old and studied Arts.Daniel has short curly hair. He loves horror movies. ',
#                                                  'location': POINT(-3.617745 40.4336),
#                                                  'name': 'Daniel',
#                                                  'age': 27,
#                                                  'gender': 'male',
#                                                  'education': 'Arts'},
#                             'facts': ['Daniel -[WORKS_AT {"since":2025}]-> Instagram', 'Cristina -[KNOWS {"knows_from":"school","text":"Cristina and Daniel are in a relaitonship."}]-> Daniel']}],
#   'processed_search_results': [],
#   'combined_context': '',
#   'search_metadata': {'element': 'node', 'source_property': 'text', 'index_used': 'person_node_idx', 'top_k': 5}}
#
# Generating embeddings
#   input text: 'Which company investigates Cancer?'...
#   emb vec: [0.03314031, 0.030437501, -0.19477448, 0.01064411, 0.07048723, 0.00393343, -0.058452524, 0.020778723, 0.0035936916, 0.003476617]
#
#
# Running vector search query
# { 'query': 'Which company investigates Cancer?',
#   'total_results': 0,
#   'raw_search_results': [ { 'score': 0.7925624847412109,
#                             'label': ['Company'],
#                             'properties_dict': { 'text': 'Accenture operates in the Consulting Services industry.',
#                                                  'location': POINT(-3.801249 40.651321),
#                                                  'name': 'Accenture',
#                                                  'industry': 'Consulting Services'},
#                             'facts': ['Iciar -[WORKS_AT {"since":2025}]-> Accenture', 'Elias -[WORKS_AT {"since":2024}]-> Accenture']},
#                           { 'score': 0.7897243499755859,
#                             'label': ['Company'],
#                             'properties_dict': { 'text': 'CBM operates in the Scientific Research industry.The CBM is a joint research centre, hosting researchers belonging to the Spanish Higher '
#                                                          'Research Council (CSIC) and the Universidad Autónoma de Madrid (UAM). Founded in 1975, the CBM is one of the largest Spanish '
#                                                          'multidisciplinary research centres in biomedicine, with expertise in molecular biology, biochemistry, genetics and genomics in several '
#                                                          'research areas: immunology, virology and microbiology, neuroscience, and cell and developmental biology.',
#                                                  'location': POINT(-3.690136 40.549613),
#                                                  'name': 'CBM',
#                                                  'industry': 'Scientific Research'},
#                             'facts': ['Cristina -[WORKS_AT {"since":2025}]-> CBM']},
#                           { 'score': 0.7851877212524414,
#                             'label': ['Company'],
#                             'properties_dict': { 'text': 'CIEMAT operates in the Scientific Research industry.The CIEMAT (Centro de Investigaciones Energéticas, Medioambientales y Tecnológicas) is a '
#                                                          'public research organization attached to the Ministry of Science, Innovation and Universities through the General Secretariat for Research. '
#                                                          'It occupies an intermediate position in the chain that runs from the creation of basic knowledge to industrial application, so its '
#                                                          'activities always seek to serve as a bridge between R&D&I and objectives of social interest.',
#                                                  'location': POINT(-3.728925 40.453938),
#                                                  'name': 'CIEMAT',
#                                                  'industry': 'Scientific Research'},
#                             'facts': ['Gabriela -[WORKS_AT {"since":2023}]-> CIEMAT']},
#                           { 'score': 0.7791872024536133,
#                             'label': ['Company'],
#                             'properties_dict': { 'text': 'Getronics operates in the Consulting Services industry.',
#                                                  'location': POINT(-3.801249 40.352321),
#                                                  'name': 'Getronics',
#                                                  'industry': 'Consulting Services'},
#                             'facts': ['Juan -[WORKS_AT {"since":2023}]-> Getronics']},
#                           { 'score': 0.7674016952514648,
#                             'label': ['Company'],
#                             'properties_dict': { 'text': 'Indra operates in the Engineering industry.Indra Group is a holding company that promotes technological progress. It includes Indra, one of '
#                                                          'the main global defense, air traffic and space companies; and Minsait, leading digital transformation and information technologies in Spain '
#                                                          'and Latin America. ',
#                                                  'location': POINT(-3.630539 40.533873),
#                                                  'name': 'Indra',
#                                                  'industry': 'Engineering'},
#                             'facts': [ 'Adrián -[WORKS_AT {"since":2023}]-> Indra',
#                                        'Javier -[WORKS_AT {"since":2023}]-> Indra',
#                                        'Paula -[WORKS_AT {"since":2024}]-> Indra',
#                                        'Iria -[WORKS_AT {"since":2025}]-> Indra',
#                                        'Guillermo -[WORKS_AT {"since":2023}]-> Indra']}],
#   'processed_search_results': [],
#   'combined_context': '',
#   'search_metadata': {'element': 'node', 'source_property': 'text', 'index_used': 'company_node_idx', 'top_k': 5}}

# %%
with driver.session(database=NEO4J_DB) as session:
# Query Relationships
  result  = helper_neo4j.neo4j_KGRAG_search(runner = session.run,
                                element = "relationship",
                                query = "Who is helping Iria at work?",
                                index = "know_relationship_idx",
                                source_property = "text",
                                main_property = "name",
                                top_k = 5
                                )
  pprint(result, width = 200, sort_dicts=False, indent=2)
  file = "data/friends/friends_context_3.txt"
  with open(file, 'w', encoding='utf-8') as f:
    f.write(result.get("combined_context", ""))
# Out:
# Generating embeddings
#   input text: 'Who is helping Iria at work?'...
#   emb vec: [-0.039116025, 0.022910928, -0.2054694, -0.0038209686, 0.038757026, -0.014443832, 0.0032659601, -0.04491874, -0.034365475, 0.03448219]
#
#
# Running vector search query
# { 'query': 'Who is helping Iria at work?',
#   'total_results': 0,
#   'raw_search_results': [ { 'score': 0.9196758270263672,
#                             'type': 'KNOWS',
#                             'properties_dict': {'text': 'Paula is helping Iria with the project she is working on.', 'knows_from': 'work'},
#                             'facts': ['Iria -[KNOWS {"knows_from":"work","text":"Paula is helping Iria with the project she is working on."}]-> Paula']},
#                           { 'score': 0.8709979057312012,
#                             'type': 'KNOWS',
#                             'properties_dict': {'text': 'Guillermo and Iria work together in the same project with AI Agents.', 'knows_from': 'work'},
#                             'facts': ['Iria -[KNOWS {"knows_from":"work","text":"Guillermo and Iria work together in the same project with AI Agents."}]-> Guillermo']},
#                           { 'score': 0.861875057220459,
#                             'type': 'KNOWS',
#                             'properties_dict': {'text': 'Paula is helping Guillermo with the project he is working on.', 'knows_from': 'work'},
#                             'facts': ['Guillermo -[KNOWS {"knows_from":"work","text":"Paula is helping Guillermo with the project he is working on."}]-> Paula']},
#                           { 'score': 0.8298172950744629,
#                             'type': 'KNOWS',
#                             'properties_dict': {'text': 'Cristina was Iria best friend in University, now they see each other every weekend.', 'knows_from': 'university'},
#                             'facts': ['Iria -[KNOWS {"knows_from":"university","text":"Cristina was Iria best friend in University, now they see each other every weekend."}]-> Cristina']},
#                           { 'score': 0.8063793182373047,
#                             'type': 'KNOWS',
#                             'properties_dict': {'text': 'Iria and Gabriela now each other because they went to University together and liked going camping.', 'knows_from': 'university'},
#                             'facts': [ 'Iria -[KNOWS {"knows_from":"university","text":"Iria and Gabriela now each other because they went to University together and liked going camping."}]-> '
#                                        'Gabriela']}],
#   'processed_search_results': [],
#   'combined_context': '',
#   'search_metadata': {'element': 'relationship', 'source_property': 'text', 'index_used': 'know_relationship_idx', 'top_k': 5}}

# %%
driver.close()
print("Driver closed.")
# Out:
# Driver closed.
